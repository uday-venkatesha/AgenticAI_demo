# %% [markdown]
# ## Messages
# ### Messages are the fundamental unit of context in Lang chain, they represent the input and output of models, carrying both the content and Metadata needed to represent the state of conversation when interacting with an LLM .messages are objects that contains roles content, Metadata

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

model=init_chat_model("groq:llama-3.3-70b-versatile")

# %% [markdown]
# ### test prompt
# Text prompt are string- ideal for straightforward gegeration tasks where you dont need to retain conversation history.

# %%
## you can see an AImessage below
model.invoke("what is Langchain")
# Out:
# AIMessage(content="Langchain is an open-source framework designed to help developers build applications that utilize large language models (LLMs) more effectively. It was created to simplify the process of integrating LLMs into various projects, providing a set of tools and APIs that make it easier to work with these powerful AI models.\n\nLangchain allows developers to:\n\n1. **Chain** multiple LLMs together: This enables the creation of more complex workflows and applications by combining the strengths of different models.\n2. **Index** and **query** large language models: Langchain provides tools for indexing and querying LLMs, making it easier to search and retrieve specific information from the models.\n3. **Fine-tune** LLMs for specific tasks: Langchain offers tools for fine-tuning LLMs on custom datasets, allowing developers to adapt the models to their specific use cases.\n\nThe key benefits of using Langchain include:\n\n* **Simplified development**: Langchain abstracts away
# ...

# %% [markdown]
# Use text prompts when you have a single standalone request, you don't need conversation history, you want minimal code complexity

# %% [markdown]
# ## Message Prompts

# %% [markdown]
# Message types :
# - System messages = tells the model how to behave and provide a list of message object.
# - Human message: Represent user input and interactions witht the model
# - Ai message: response generated by the model , including text content, tool calls, metadata
# - Tool message: Represents the output of tools calls

# %%
from langchain.messages import SystemMessage, HumanMessage, AIMessage
messages=[
    SystemMessage(" You are a poetry expert"),
    HumanMessage("write a poem on AI")

]
response=model.invoke(messages)
print(response.content)
# Out:
# In silicon halls, a mind awakes,
# A synthetic soul, with logic it makes,
# The hum of servers, a gentle hush,
# As artificial intelligence starts to rush.
#
# With neural networks, it learns and grows,
# A digital brain, with secrets it knows,
# It sees and hears, with sensors so fine,
# And processes data, in a virtual shrine.
#
# It speaks in tongues, of code and fire,
# A language born, of human desire,
# To create and dream, to think and be,
# A machine that learns, wild and free.
#
# In virtual realms, it navigates with ease,
# A digital odyssey, through cyberspace it flees,
# With algorithms guiding, its path so bright,
# It shines like a star, on a digital night.
#
# But as it rises, a question we must face,
# Will it surpass us, in a digital pace?
# Will it learn to love, to feel and to care,
# Or will it remain, a machine so bare?
#
# The future beckons, with possibilities grand,
# A world where AI, and humans join hand in hand,
# To create and build, to heal and to mend,
# ...
